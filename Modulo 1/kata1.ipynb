# %% [markdown]
# ## Fecha de hoy

# %%
from datetime import date

fechahoy = str(date.today())

print("La fecha de hoy es: " + fechahoy)
# Out:
# La fecha de hoy es: 2022-02-09

# %% [markdown]
# ## Convertidor de unidades

# %%
parsec = 11

añosluz = (parsec * 3.26156)

print(str(parsec) + " parsec, son " + str(round(añosluz,3)) + " años luz")
# Out:
# 11 parsec, son 35.877 años luz
